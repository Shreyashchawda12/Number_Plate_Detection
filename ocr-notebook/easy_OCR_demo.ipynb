# %%
# !pip install easyocr

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import matplotlib.pyplot as plt
import cv2
import easyocr
from IPython.display import Image

# %%
img = Image("/content/number_plate_01.jpeg")

# %%
img

# %%
reader = easyocr.Reader(['en'])

# %%
output = reader.readtext('/content/number_plate_01.jpeg')

# %%
output
# Out:
# [([[80, 116], [158, 116], [158, 148], [80, 148]], 'MH 03', 0.3754100900613522),
#  ([[77, 145], [93, 145], [93, 167], [77, 167]], 'P', 0.6005942908874573),
#  ([[95, 139], [167, 139], [167, 175], [95, 175]], '2521', 0.9999628067016602)]

# %%
cord = output[-1][0]

# %%
cord
# Out:
# 0.9999628067016602

# %%
a = list(zip(*cord))
a
# Out:
# [(95, 167, 167, 95), (139, 139, 175, 175)]

# %%
a
# Out:
# [(95, 167, 167, 95), (139, 139, 175, 175)]

# %%
min(a[0])
# Out:
# 95

# %%
min(a[1])
# Out:
# 139

# %%
max(a[0])
# Out:
# 167

# %%
max(a[1])
# Out:
# 175

# %%
x_min, y_min = [int(min(idx)) for idx in zip(*cord)]

# %%
x_min, y_min
# Out:
# (95, 139)

# %%
x_max, y_max = [int(max(idx)) for idx in zip(*cord)]

# %%
x_max, y_max
# Out:
# (167, 175)

# %%
from pylab import rcParams
rcParams['figure.figsize'] = 20, 30

# %%
image = cv2.imread('/content/number_plate_01.jpeg')
cv2.rectangle(image,(x_min,y_min),(x_max,y_max),(0,0,255),2)
plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))

# %%
# Out:
# Running cells with 'detection' requires the ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: 'conda install -n detection ipykernel --update-deps --force-reinstall'
